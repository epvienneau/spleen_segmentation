# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# %%
orig = nib.load('data/testing/img/img0077.nii.gz').get_fdata()[:,:,117]
# %matplotlib inline
plt.imshow(orig, cmap='gray')

# %%
pred = nib.load('data/testing/results/img0077.nii.gz').get_fdata()[:,:,150]
# %matplotlib inline
plt.imshow(pred, cmap='gray')

# %%
vol_slice = nib.load('data/testing/img/img0077.nii.gz')
vol_slice_hdr = vol_slice.header
print(vol_slice_hdr)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 512 512 151   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [ 1.          0.78515625  0.78515625  3.          0.          0.          0.
#   0.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 2976
# glmin           : -1024
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : unknown
# quatern_b       : 0.0
# ...

# %%
sliced = nib.load('data/testing/slices/img/img0077_117.nii.gz')
sliced_hdr = sliced.header
print(sliced_hdr)

# %%
pred = nib.load('data/testing/slices/pred/img0077_117.nii.gz')
pred_hdr = pred.header
print(pred_hdr)

# %%
result = nib.load('data/testing/results/img0077.nii.gz')
result_hdr = result.header
print(result_hdr)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 512 512 151   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [ 1.          0.78515625  0.78515625  3.          1.          1.          1.
#   1.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 2976
# glmin           : -1024
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.0
# ...

# %%
result_hdr['pixdim'] = vol_slice_hdr['pixdim']
print(result_hdr['pixdim'])

# %%
from utils import save
save(result.get_fdata(), 'tester.nii.gz', result_hdr)
tester = nib.load('tester.nii.gz')
print(tester.header)

# %%
import os
files = sorted(os.listdir('data/testing/slices/img/'), key=int)
print(files)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-71a2ab81fd7a> in <module>()
#       1 import os
# ----> 2 files = sorted(os.listdir('data/testing/slices/img/'), key=int)
#       3 print(files)
#
# ValueError: invalid literal for int() with base 10: 'img0074_48.nii.gz'
